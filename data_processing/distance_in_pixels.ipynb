# %%
import os
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import math
import cv2

# %%
image_save_dir = 'test2.jpg'
image = Image.open(image_save_dir)

# %%
#display(img)

org_image_array = np.array(image)

# calculate images and rows
rows = org_image_array.shape[0]
column = org_image_array.shape[1]

print(rows,column)
# Out:
# 1080 1920

# %%
x = 0
while x < rows:
    y = 0
    t = 0
    #while y < 24:
    #    org_image_array[x,t+x//10,:] = 0
    #    y = y+1
    #    t = y*26

    org_image_array[x,252+x//17,:] = 250
    org_image_array[x,257+x//17,:] = 250
    org_image_array[x,410+x//17,:] = 250
    
    x = x +1
    
image_from_array = Image.fromarray(org_image_array)
image_from_array
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %%
theta = math.atan(1/17)
print((410-252)*math.cos(theta), "pix = 80 micrometers" )
print()
# Out:
# 157.72735096164936 pix = 80 micrometers

# %%
print("1 pix = ", 80/157.72 ,"micrometers" )
# Out:
# 1 pix =  0.507227998985544 micrometers

# %%
print(round(2.8689/0.50722,2),"X Magnification gain")
# Out:
# 5.66 X Magnification gain

# %% [markdown]
# #### 157.727 pix = 80 $\mu m$
#
# #### 1 pix =  0.5072 $\mu m$
#
# 5.66 X Magnification gain

# %%
image_cv = cv2.imread(image_save_dir)

# %%
25*20
# Out:
# 500

# %%
100/12
# Out:
# 8.333333333333334

# %%
360*4/(2*math.pi)
# Out:
# 229.1831180523293
